# %% [markdown]
# # Exploración de datos

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
from functools import reduce
import copy
from collections import OrderedDict
import datetime

project_path = os.path.abspath('../')
sys.path.insert(1, project_path)

import pandas as pd
import numpy as np
from scipy.stats import circmean

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set_context('talk')

from src.utils import get_project_root
from src.data.make_dataset import get_minma_data
from src.eda.processing import *
from src.eda.visualization import plot_temp, conf_matrix
import dataframe_image as dfi
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Carga de datos

# %% [markdown]
# ### Variables y ventana de análisis

# %%
params = ['SO2','NO2', 'NO', 'NOX', 'O3', 'CO']
from_last = '5y'

# %% [markdown]
# ### Datos

# %%
data_df = get_minma_data(params, 'quintero', from_last=from_last)
data_df = data_df.filter(regex=("Registros no validados_"))
data_df.columns = data_df.columns.str.strip('Registros no validados_')

meteo_df = pd.read_excel(get_project_root() / 'data' / 'raw' / 'Torre Meteo Codelco Ventanas.xlsx').set_index('date')
meteo_df['T_diff'] = 100*(meteo_df['T_40'] - meteo_df['T_10']) / 30

cems_df = pd.read_excel(get_project_root() / 'data' / 'raw' / 'CEMS industrial datos Quintero.xlsx', index_col=0, skiprows=2)
# Out:
# /home/agonzalez/projects/mds7201-minma-so2/src/data/make_dataset.py:62: FutureWarning: Units 'M', 'Y' and 'y' do not represent unambiguous timedelta values and will be removed in a future version.
#   from_date = to_date - pd.Timedelta(from_last)

# %% [markdown]
# ### Merge de datos

# %%
data_df = pd.merge(meteo_df, data_df, left_index=True, right_index=True)
# [['T_diff', 'T_20', 'HR_20', 'P_20', 'WS_20', 'WD_20']]
data_df = pd.merge(cems_df, data_df, left_index=True, right_index=True)
data_df.head()
# Out:
#                      CEMS U1 Ventanas  CEMS U2 Ventanas  CEMS U3 Ventanas  \
# 2019-08-01 01:00:00               NaN               NaN               NaN
# 2019-08-01 02:00:00               NaN               NaN               NaN
# 2019-08-01 03:00:00               NaN               NaN               NaN
# 2019-08-01 04:00:00               NaN               NaN               NaN
# 2019-08-01 05:00:00               NaN               NaN               NaN
#
#                      CEMS U4 Ventanas  CEMS Chimenea Codelco  \
# 2019-08-01 01:00:00               NaN                    NaN
# 2019-08-01 02:00:00               NaN                    NaN
# 2019-08-01 03:00:00               NaN                    NaN
# 2019-08-01 04:00:00               NaN                    NaN
# 2019-08-01 05:00:00               NaN                    NaN
#
#                      CEMS Planta Acido Codelco     T_10      T_20     T_40  \
# 2019-08-01 01:00:00                        NaN  9.32983  10.09780  9.07899
# 2019-08-01 02:00:00                        NaN  8.65620   9.47633  8.43515
# 2019-08-01 03:00:00                        NaN  8.06523   8.97534  7.88302
# 2019-08-01 04:00:00                        NaN  7.95675   8.67967  7.68432
# 2019-08-01 05:00:00                        NaN  7.95688   8.86282  7.96602
#
#                        WD_10  ...    HR_20    HR_40     P_20    T_diff   SO2  \
# 2019-08-01 01:00:00  194.392  ...  59.6488  60.0490  1020.00 -0.836133  2.57
# 2019-08-01 02:00:00  154.067  ...  62.3453  62.6893  1020.02 -0.736833  2.34
# 2019-08-01 03:00:00  134.585  ...  64.6565  65.0258  1020.00 -0.607367  2.47
# 2019-08-01 04:00:00  184.304  ...  65.4817  65.6469  1020.00 -0.908100  2.88
# 2019-08-01 05:00:00  171.480  ...  63.6508  63.1445  1020.00  0.030467  3.77
#
#                       NO2       NO      NOX    O3    CO
# 2019-08-01 01:00:00  3.24  1.47358  4.64126  31.0  0.17
# 2019-08-01 02:00:00  3.62  1.55860  5.09715  29.0  0.17
# 2019-08-01 03:00:00  3.26  1.52150  4.70790  30.0  0.17
# 2019-08-01 04:00:00  4.21  1.48963  5.61110  27.0  0.18
# 2019-08-01 05:00:00  5.13  1.54147  6.56435  26.0  0.17
#
# [5 rows x 29 columns]

# %% [markdown]
# ## División por días de peaks

# %%
# Separación de días normales y peaks
_, peak_days = get_SO2_peaks(data_df, 'SO2', 130)
_, limit_days = get_SO2_limit(data_df, 'SO2', 130)

# Filtro de dataframe según el tipo de día
data_peaks_df = filter_by_dates(data_df, peak_days)
data_limit50_df = filter_by_dates(data_df, limit_days)

# %% [markdown]
# ## Distribución acumulada de distintas métricas

# %%
plot_temp([data_peaks_df, data_limit50_df], 'Quintero', type='cumdistr')
# Out:
# /home/agonzalez/projects/mds7201-minma-so2/src/eda/visualization.py:216: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## Matriz de confusion

# %%
fig, ax = plt.subplots(figsize=(40,60))
conf_matrix(data_df, ax=ax)
ax.set_title('Matriz de confusión - Quintero', y=1.02)
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
conf_matrix(data_df, SO2_only=True, ax=ax)
ax.set_title('Variables más correlacionadas con SO2 - Quintero', y=1.02)
plt.show()
