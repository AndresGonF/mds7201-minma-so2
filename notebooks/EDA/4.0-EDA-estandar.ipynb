# %% [markdown]
# # Exploración de datos

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
from functools import reduce

project_path = os.path.abspath('..')
sys.path.insert(1, project_path)

import pandas as pd
import numpy as np
from scipy.stats import circmean

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

from src.utils import get_project_root
from src.data.make_dataset import get_minma_data
from src.visualization.trends import visualizar_trends
from src.visualization.eda import *

# %% [markdown]
# ## EDA - {datos}

# %% [markdown]
# ### Carga de datos

# %%
data_df = pd.read_excel(get_project_root() / 'data' / 'raw' / 'CEMS industrial datos Quintero.xlsx', header=2, index_col=0)

# %%
data_df.head()
# Out:
#                      CEMS U1 Ventanas  CEMS U2 Ventanas  CEMS U3 Ventanas  \
# date
# 2019-08-01 01:00:00               NaN               NaN               NaN
# 2019-08-01 02:00:00               NaN               NaN               NaN
# 2019-08-01 03:00:00               NaN               NaN               NaN
# 2019-08-01 04:00:00               NaN               NaN               NaN
# 2019-08-01 05:00:00               NaN               NaN               NaN
#
#                      CEMS U4 Ventanas  CEMS Chimenea Codelco  \
# date
# 2019-08-01 01:00:00               NaN                    NaN
# 2019-08-01 02:00:00               NaN                    NaN
# 2019-08-01 03:00:00               NaN                    NaN
# 2019-08-01 04:00:00               NaN                    NaN
# 2019-08-01 05:00:00               NaN                    NaN
#
#                      CEMS Planta Acido Codelco
# date
# 2019-08-01 01:00:00                        NaN
# 2019-08-01 02:00:00                        NaN
# 2019-08-01 03:00:00                        NaN
# 2019-08-01 04:00:00                        NaN
# 2019-08-01 05:00:00                        NaN

# %% [markdown]
# ### Data info

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 27711 entries, 2019-08-01 01:00:00 to 2022-09-28 15:00:00
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CEMS U1 Ventanas           12388 non-null  float64
#  1   CEMS U2 Ventanas           16786 non-null  float64
#  2   CEMS U3 Ventanas           18760 non-null  float64
#  3   CEMS U4 Ventanas           19586 non-null  float64
#  4   CEMS Chimenea Codelco      15021 non-null  float64
#  5   CEMS Planta Acido Codelco  19703 non-null  float64
# dtypes: float64(6)
# memory usage: 1.5 MB

# %% [markdown]
# ### Visualización inicial

# %%
# ylabel_list -> label en eje y para cada variable
series_plot(data_df,
            ylabel_list=['SO2 [ppm/hr]']*data_df.shape[1])

# %% [markdown]
# ### Datos nulos

# %%
data_df.isna().sum()
# Out:
# CEMS U1 Ventanas             15323
# CEMS U2 Ventanas             10925
# CEMS U3 Ventanas              8951
# CEMS U4 Ventanas              8125
# CEMS Chimenea Codelco        12690
# CEMS Planta Acido Codelco     8008
# dtype: int64

# %%
# xlabel_list -> label en eje x para cada variable
# args = {'xscale':'log', 'yscale':'log'} # -> Descomentar para aplica escala logaritmica 
hist_plot(data_df, xlabel_list=['SO2 [ppm/hr]']*data_df.shape[1]) #, **args) -> Opcional para escala logaritmica, u otros parámetros
# Out:
# /home/agonzalez/projects/mds7201-minma-so2/src/visualization/eda.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks(), rotation = 45)

# %% [markdown]
# ### Resumen estadístico

# %%
data_df.describe()
# Out:
#        CEMS U1 Ventanas  CEMS U2 Ventanas  CEMS U3 Ventanas  CEMS U4 Ventanas  \
# count      12388.000000      16786.000000      18760.000000      19586.000000
# mean          12.553066        266.664728        267.960240        254.333037
# std           35.598075         62.860692         76.038918         89.209258
# min            0.025691          0.072111          0.000000          0.000000
# 25%            1.071545        237.723750        231.588250        216.972250
# 50%            1.971170        274.011500        287.927500        279.314500
# 75%            3.053872        301.451000        318.527500        315.101500
# max          361.922000       1136.140000        917.834000       1084.550000
#
#        CEMS Chimenea Codelco  CEMS Planta Acido Codelco
# count           15021.000000               19703.000000
# mean              628.224463                 359.028793
# std               447.889732                 282.253395
# min                 0.000000                   0.000000
# 25%               310.120000                  97.883150
# 50%               568.606000                 327.583000
# 75%               874.874000                 579.797000
# max              3727.310000                1648.650000

# %% [markdown]
# ### Cantidad de datos por fecha

# %% [markdown]
# ### Lag plots

# %% [markdown]
# #### 1 hora

# %%
lag_plot(data_df, lag=1, unit='horas')

# %% [markdown]
# #### 1 día

# %%
lag_plot(data_df, lag=24, unit='horas')

# %% [markdown]
# ### Correlaciones entre datos

# %% [markdown]
# #### Pair plot

# %%
sns.pairplot(data_df)
plt.show()

# %% [markdown]
# #### Matriz de confusion

# %%
conf_matrix(data_df)

# %% [markdown]
# ### Trends

# %%
visualizar_trends(data_df, col = "CEMS U2 Ventanas", ano_0=2021, title='Emisiones CEMS U2 Ventanas')

# %% [markdown]
# ### Estadísticos por períodos

# %% [markdown]
# #### Anual

# %%
time_describe(data_df, col='CEMS U4 Ventanas', res='y', from_date=data_df.index[0], to_date=data_df.index[-1], highlights=True)
# Out:
# <style type="text/css">
# #T_20991_row0_col0, #T_20991_row0_col1, #T_20991_row0_col2, #T_20991_row0_col3, #T_20991_row0_col4, #T_20991_row0_col5, #T_20991_row0_col6, #T_20991_row0_col7, #T_20991_row1_col3, #T_20991_row2_col3 {
#   background-color: red;
# }
# #T_20991_row1_col0, #T_20991_row1_col7, #T_20991_row2_col2, #T_20991_row2_col5, #T_20991_row2_col6, #T_20991_row3_col1, #T_20991_row3_col3, #T_20991_row3_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_20991">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20991_level0_col0" class="col_heading level0 col0" colspan="8">CEMS U4 Ventanas</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_20991_level1_col0" class="col_heading level1 col0" >count</th>
#       <th id="T_20991_level1_col1" class="col_heading level1 col1" >mean</th>
#       <th id="T_20991_level1_col2" class="col_heading level1 col2" >std</th>
#       <th id="T_20991_level1_col3" class="col_heading level1 col3" >min</th>
#       <th id="T_20991_level1_col4" class="col_heading level1 col4" >25%</th>
#       <th id="T_20991_level1_col5" class="col_heading level1 col5" >50%</th>
#       <th id="T_20991_level1_col6" class="col_heading level1 col6" >75%</th>
#       <th id="T_20991_level1_col7" class="col_heading level1 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >y</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20991_level0_row0" class="row_heading level0 row0" >19</th>
#       <td id="T_20991_row0_col0" class="data row0 col0" >45.00</td>
#       <td id="T_20991_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_20991_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_20991_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_20991_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_20991_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_20991_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_20991_row0_col7" class="data row0 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_20991_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_20991_row1_col0" class="data row1 col0" >7810.00</td>
#       <td id="T_20991_row1_col1" class="data row1 col1" >245.38</td>
#       <td id="T_20991_row1_col2" class="data row1 col2" >90.44</td>
#       <td id="T_20991_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_20991_row1_col4" class="data row1 col4" >213.26</td>
#       <td id="T_20991_row1_col5" class="data row1 col5" >263.58</td>
#       <td id="T_20991_row1_col6" class="data row1 col6" >303.77</td>
#       <td id="T_20991_row1_col7" class="data row1 col7" >1084.55</td>
#     </tr>
#     <tr>
#       <th id="T_20991_level0_row2" class="row_heading level0 row2" >21</th>
#       <td id="T_20991_row2_col0" class="data row2 col0" >6989.00</td>
#       <td id="T_20991_row2_col1" class="data row2 col1" >253.00</td>
#       <td id="T_20991_row2_col2" class="data row2 col2" >99.46</td>
#       <td id="T_20991_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_20991_row2_col4" class="data row2 col4" >214.36</td>
#       <td id="T_20991_row2_col5" class="data row2 col5" >290.43</td>
#       <td id="T_20991_row2_col6" class="data row2 col6" >322.48</td>
#       <td id="T_20991_row2_col7" class="data row2 col7" >647.25</td>
#     </tr>
#     <tr>
#       <th id="T_20991_level0_row3" class="row_heading level0 row3" >22</th>
#       <td id="T_20991_row3_col0" class="data row3 col0" >4742.00</td>
#       <td id="T_20991_row3_col1" class="data row3 col1" >273.46</td>
#       <td id="T_20991_row3_col2" class="data row3 col2" >60.91</td>
#       <td id="T_20991_row3_col3" class="data row3 col3" >22.93</td>
#       <td id="T_20991_row3_col4" class="data row3 col4" >231.77</td>
#       <td id="T_20991_row3_col5" class="data row3 col5" >289.15</td>
#       <td id="T_20991_row3_col6" class="data row3 col6" >321.39</td>
#       <td id="T_20991_row3_col7" class="data row3 col7" >385.81</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Mensual

# %%
time_describe(data_df, col='CEMS U4 Ventanas', res='m', from_date=data_df.index[0], to_date=data_df.index[-1])
# Out:
#    CEMS U4 Ventanas                                                         \
#               count        mean         std       min        25%       50%
# m
# 01            762.0  283.014505   63.982405    0.0000  252.68775  301.2575
# 02            832.0  286.173931   49.509554  118.3040  264.09300  299.4370
# 03           1932.0  238.381495  131.987433    0.0000  206.02700  288.2625
# 04           2150.0  282.810027   47.800879  101.0630  261.99525  295.0975
# 05           2214.0  261.219436   60.356314   10.6843  216.24675  277.8520
# 06           2123.0  256.252304  108.873173    0.0000  224.63900  290.3020
# 07           2058.0  270.031481   72.079516    0.0000  224.35250  288.5760
# 08           1892.0  208.072907  112.442806    0.0000  172.90075  225.6135
# 09           1448.0  209.704372   97.557150    0.0000  184.45925  224.2545
# 10           1315.0  239.754812   67.444587    0.0000  209.69000  249.6600
# 11           1395.0  259.613680   71.998410    0.0000  215.78150  262.0290
# 12           1465.0  277.246217   58.616607    0.0000  248.57200  293.0440
#
#
#           75%       max
# m
# 01  330.18250   369.441
# 02  320.10100   373.880
# 03  320.18525  1084.550
# 04  316.64775   386.019
# 05  309.23175   384.421
# 06  321.48000  1078.120
# 07  326.06950   630.054
# 08  305.98475   368.071
# 09  277.85500   374.218
# 10  287.77400   368.204
# 11  316.57900   426.041
# 12  315.91000   647.246

# %% [markdown]
# #### Diario

# %%
